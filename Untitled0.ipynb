# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana1320/AIML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=6
s=5+6
print(s)
# Out:
# 11

# %%
numbers = [1, 2, 3, 4, 5]


print("Original list:", numbers)

# Append a new element to the list
numbers.append(6)
print("After appending 6:", numbers)

# Insert an element at a specific position
numbers.insert(2, 10)
print("After inserting 10 at index 2:", numbers)

# Remove an element from the list
numbers.remove(4)
print("After removing 4:", numbers)

# Pop an element from the list
popped_element = numbers.pop()
print("After popping an element:", numbers)
print("Popped element:", popped_element)

# Sort the list
numbers.sort()
print("After sorting:", numbers)

# Reverse the list
numbers.reverse()
print("After reversing:", numbers)

# Get the length of the list
length = len(numbers)
print("Length of the list:", length)
# Out:
# Original list: [1, 2, 3, 4, 5]
# After appending 6: [1, 2, 3, 4, 5, 6]
# After inserting 10 at index 2: [1, 2, 10, 3, 4, 5, 6]
# After removing 4: [1, 2, 10, 3, 5, 6]
# After popping an element: [1, 2, 10, 3, 5]
# Popped element: 6
# After sorting: [1, 2, 3, 5, 10]
# After reversing: [10, 5, 3, 2, 1]
# Length of the list: 5

# %%
n=[1,2,3,4]
n.append(6)
print("after appending 6:",n)
# Out:
# after appending 6: [1, 2, 3, 4, 6]

# %%
import numpy as np
import pandas as pd
print("LISTS")
a=[1,2,3,4,5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,0])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATIO AND DIVISION OF ARRAYS")
mult_array=array1*array2
print("multiplication of array",mult_array)
div_array=array1/array2
print("division of array",div_array)
print("ADDITION OF ARRAY")
add=array1+array2
print(add)
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))vimport numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))vimport numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
# Out:
# LISTS
# [1, 2, 3, 4, 5]
# ARRAYS
# [6 7 8 9 0]
# [1 2 3 4 5]
# DATA TYPES
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# MULTIPLICATIO AND DIVISION OF ARRAYS
# multiplication of array [ 6 14 24 36  0]
# division of array [6.         3.5        2.66666667 2.25       0.        ]
# ADDITION OF ARRAY
# [ 7  9 11 13  5]

# %%
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))

import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([1,2,3,4,5])
array2=np.array([2,9,4,6,8])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
# Out:
#   File "<ipython-input-6-e9302a88e68e>", line 35
#     print(np.log2(array1))import numpy as np
#                           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
# Out:
# LISTS
# [1, 2, 3, 4, 5]
# ARRAYS
# [6 7 8 9 5]
# [1 2 3 4 5]
# DATA TYPES
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# MULTIPLICATION AND DIVISION OF ARRAYS
# Multiplication of array1 and array2: [ 6 14 24 36 25]
# Division of array2 by array1: [0.16666667 0.28571429 0.375      0.44444444 1.        ]
# Power of array1 elements: [36 49 64 81 25]
# ADDITION OF ARRAYS
# [ 7  9 11 13 10]
# IMPLEMENTATIONS
# Exponential of array1: [ 403.42879349 1096.63315843 2980.95798704 8103.08392758  148.4131591 ]
# Sine of array1: [-0.2794155   0.6569866   0.98935825  0.41211849 -0.95892427]
# LOG()
# [1.79175947 1.94591015 2.07944154 2.19722458 1.60943791]
# LOG2
# [2.5849625  2.80735492 3.         3.169925   2.32192809]
# LISTS
# [1, 2, 3, 4, 5]
# ARRAYS
# [6 7 8 9 5]
# [1 2 3 4 5]
# DATA TYPES
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# MULTIPLICATION AND DIVISION OF ARRAYS
# Multiplication of array1 and array2: [ 6 14 24 36 25]
# Division of array2 by array1: [0.16666667 0.28571429 0.375      0.44444444 1.        ]
# Power of array1 elements: [36 49 64 81 25]
# ADDITION OF ARRAYS
# [ 7  9 11 13 10]
# IMPLEMENTATIONS
# Exponential of array1: [ 403.42879349 1096.63315843 2980.95798704 8103.08392758  148.4131591 ]
# Sine of array1: [-0.2794155   0.6569866   0.98935825  0.41211849 -0.95892427]
# LOG()
# [1.79175947 1.94591015 2.07944154 2.19722458 1.60943791]
# LOG2
# [2.5849625  2.80735492 3.         3.169925   2.32192809]
# LISTS
# [1, 2, 3, 4, 5]
# ARRAYS
# [6 7 8 9 5]
# [1 2 3 4 5]
# DATA TYPES
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# MULTIPLICATION AND DIVISION OF ARRAYS
# Multiplication of array1 and array2: [ 6 14 24 36 25]
# Division of array2 by array1: [0.16666667 0.28571429 0.375      0.44444444 1.        ]
# Power of array1 elements: [36 49 64 81 25]
# ADDITION OF ARRAYS
# [ 7  9 11 13 10]
# IMPLEMENTATIONS
# Exponential of array1: [ 403.42879349 1096.63315843 2980.95798704 8103.08392758  148.4131591 ]
# Sine of array1: [-0.2794155   0.6569866   0.98935825  0.41211849 -0.95892427]
# LOG()
# [1.79175947 1.94591015 2.07944154 2.19722458 1.60943791]
# LOG2
# [2.5849625  2.80735492 3.         3.169925   2.32192809]
